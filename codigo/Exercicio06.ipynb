# %% [markdown]
# # Algoritmo para gerar variáveis aleatórias geométrica

# %%
import random

def geometric_random_variable(p):
    u = random.random()  # Gera uma variável aleatória uniforme entre 0 e 1
    x = int(1 + (math.log(1 - u) / math.log(1 - p)))  # Calcula a variável aleatória geométrica
    return x

# %%
p = 20 / (30 + 20)  # Probabilidade de sucesso (bola preta)
x = 6  # Número de tentativas
probabilidade = p * ((1 - p) ** (x - 1))

print("Probabilidade de que a 6ª bola retirada com reposição seja a primeira bola preta:", probabilidade)
# Out:
# Probabilidade de que a 6ª bola retirada com reposição seja a primeira bola preta: 0.031103999999999993
